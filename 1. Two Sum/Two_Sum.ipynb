# %% [markdown]
# # Cnotes

# %%
# %%file Two_Sum.c
#
# #include <stdio.h>
#
# int main() {
#     printf("Hello, World!\n");
#     return 0;
# }
# Out:
# Writing Two_Sum.c

# %%
# !gcc Two_Sum.c -o Two_Sum

# %%
# !Two_Sum
# Out:
# Hello, World!
