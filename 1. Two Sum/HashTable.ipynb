# %% [markdown]
# # Hash Table (Best Solution)

# %% [markdown]
# Look at the current number.

# %% [markdown]
# Calculate the number you need: complement = target - nums[i];

# %% [markdown]
# Check if that complement is already in the hash table.

# %% [markdown]
# If yes, you've found the answer.

# %% [markdown]
# Otherwise, store the current number and its index.

# %%
# %%file Two_Sum.c
# #include <stdio.h>
# #include <stdlib.h>
#
# #define TABLE_SIZE 1009
#
#
#
# Node *hashTable[TABLE_SIZE];
#
# int hash(int key)
# {
#     if (key < 0)
#         key = -key;
#     return key % TABLE_SIZE;
# }
#
# // Insert number and its index
# void insert(int key, int value)
# {
#     int index = hash(key);
#
#     Node *newNode = (Node *)malloc(sizeof(Node));
#
#     newNode->key = key;
#     newNode->value = value;
#     newNode->next = hashTable[index];
#
#     hashTable[index] = newNode;
# }
#
# int srearch (int key) // search(24)
# {
#     // search for the key in the hash table
#     int index = hash(key); // hash(24)
#     Node *current = hashTable[index];
#     while (current != NULL)
#     {
#         if (curent->key == key)
#         {
#             return current->value;
#         }
#         current = current->next;
#     }
#     return -1; // Key not found
#
# }
#
# void twoSum(int nums[], int target, int size)
# {
#     for (int i = 0 ; i < size ; i ++)
#     {
#         int complement = target - nums[i]; // 26 - 2
#         int index = search (complement);// search(24)
#         if (index != -1)
#         {
#             printf("[%d,%d]\n", index, i);
#             return;
#         }
#         insert(nums[i], i); // insert(2,0)
#     }
#     printf("No solution found\n");
#
# }
# int main()
# {
#     int nums[] = {2, 7, 11, 15};
#     int target = 26;
#     int size = sizeof(nums) / sizeof(nums[0]);
#     Two_Sum(nums, target, size);
#     freeTable();
#     return 0;
# }
# Out:
# Overwriting Two_Sum.c
